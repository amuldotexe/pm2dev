# %% [markdown]
# # Notes of Rust while exploring Apache Iggy

# %% [markdown]
# ``` text
#
# This is where we'll make all our notes.
#
# It's going to include anything from screenshots to actual code snippets to explanations.
#
#
#
# ```

# %% [markdown]
# ``` text
# CORE/CONNECTORS TODAY
#
# The shape is:
#
# +----------------------------------------------+
# | core/connectors                              |
# +----------------------------------------------+
# | README.md            -> platform overview     |
# | sdk/                 -> traits + FFI macros   |
# | runtime/             -> load and run plugins  |
# | sinks/*              -> consume from Iggy     |
# | sources/*            -> produce into Iggy     |
# +----------------------------------------------+
#
# ---
# SECTION 1: THE TOP-LEVEL SPLIT
#
# +------------------+      +------------------+      +------------------+
# | sdk              | ---> | runtime          | ---> | plugin crates    |
# | contract         |      | orchestration    |      | actual behavior  |
# +------------------+      +------------------+      +------------------+
#
# sdk answers:
#   "What is a Sink or Source?"
#
# runtime answers:
#   "How do we load, configure, and run them?"
#
# plugin crate answers:
#   "What should this connector actually do?"
#
#
# ```

# %% [markdown]
# ### Rust vs Java Generics

# %% [markdown]
# ![alt text](image-2.png)
